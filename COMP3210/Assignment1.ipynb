# %% [markdown]
# # COMP3210 Assignment 1
# ## Part B
#
# Name: Jack Mey
#
# StudentID: 45345201

# %%
#### Import the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pymongo # import pip install pymongo from terminal

# %%
from pymongo import MongoClient # import pip install dnspython from terminal
client = MongoClient('mongodb+srv://jack:abcd1234@cluster0-jompo.mongodb.net/test?retryWrites=true&w=majority')

# %%
## connect to the database in MongoDB
db = client.test

# %%
## refer to the collection Tweets in MongoDB
collection = db.Tweets

# %%
## crete a dataframe of the documents from the Tweets collection in MongoDB
data = pd.DataFrame(list(collection.find()))
data
# Out:
#                          _id                      created_at  \
# 0   5e6efb70b6f92d587aaf55f9  Thu Apr 06 15:24:15 +0000 2017
# 1   5e6efb70b6f92d587aaf55fa  Thu Apr 06 15:24:16 +0000 2017
# 2   5e6efb70b6f92d587aaf55fb  Thu Apr 06 15:24:17 +0000 2017
# 3   5e6efb70b6f92d587aaf55fc  Thu Apr 06 15:24:18 +0000 2017
# 4   5e6efb71b6f92d587aaf55fd  Thu Apr 06 15:24:19 +0000 2017
# 5   5e6efb71b6f92d587aaf55fe  Thu Apr 06 15:24:20 +0000 2017
# 6   5e6efb71b6f92d587aaf55ff  Thu Apr 06 15:24:21 +0000 2017
# 7   5e6efb71b6f92d587aaf5600  Thu Apr 06 15:24:22 +0000 2017
# 8   5e6efb71b6f92d587aaf5601  Thu Apr 06 15:24:23 +0000 2017
# 9   5e6efb71b6f92d587aaf5602  Thu Apr 06 15:24:24 +0000 2017
# 10  5e6efb71b6f92d587aaf5603  Thu Apr 06 15:24:25 +0000 2017
# 11  5e6efb71b6f92d587aaf5604  Thu Apr 06 15:24:26 +0000 2017
# 12  5e6efb71b6f92d587aaf5605  Thu Apr 06 15:24:27 +0000 2017
# 13  5e6efb71b6f92d587aaf5606  Thu Apr 06 15:24:28 +0000 2017
# ...

# %%
data1 = data['text']
data1.head(10)
# Out:
# 0    Train people well enough so they can leave, tr...
# 1    On Friday evening we welcomed our new MRes and...
# 2    Excited to publish the BPM Newsletter 1-2018, ...
# 3    Our social networks  amplify negative more tha...
# 4    Welcome to the official Department of Computin...
# 5    Watch this incredible @TEDTalks with IBM scien...
# 6    A man with Down Syndrome, with help from his D...
# 7    Be a good person, but don't waste your time tr...
# 8    Have you started writing your #BPM2018 paper? ...
# 9    The final http://deeplearning.ai  course on Se...
# Name: text, dtype: object

# %%
### importing cleaning libraries
import re # allows use of Regular Expressions (i.e. to keep letters and numbers)
import nltk # most common and easy to use data pre-processing library
from nltk.stem.porter import PorterStemmer # stemming is the process of producing
# morphological variants of a root/base word
nltk.download('stopwords') # standard stopwords list
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize

corpus = []

for i in range(0, len(data1)):
    review = re.sub('[^a-zA-Z0-9]', ' ', data1[i]) ## keeping letters and numbers
    review = review.lower() ## converting to lowercase
    review = review.split() ## split each sentence into individual words for each record
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Jack
# [nltk_data]     Mey\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
corpus
# Out:
# ['train peopl well enough leav treat well enough want richardbranson',
#  'friday even welcom new mre phd student walk tour citi intern student enjoy see sight sydney cityofsydney macquarieuniexperi macquari uni mqintl mqscieng',
#  'excit publish bpm newslett 1 2018 first one download http tinyurl com y7ync633 bpmconf bpm2018',
#  'social network amplifi neg posit great articl http washingtonmonthli com magazin januari februari march 2018 fix facebook fix us cc webfound',
#  'welcom offici depart comput comput mq twitter account',
#  'watch incred tedtalk ibm scientist bmibruno titl brain keep ai stay tune fun end hint look shoe tedatibm',
#  'man syndrom help dad use million dollar compani show world peopl learn disabl capabl amaz',
#  'good person wast time tri prove',
#  'start write bpm2018 paper one month left till abstract submiss http bpm2018 web cse unsw edu au call paper html',
# ...

# %%
new_list = []
for row in corpus:
    new_list.append(row.split(" "))
new_list
# Out:
# [['train',
#   'peopl',
#   'well',
#   'enough',
#   'leav',
#   'treat',
#   'well',
#   'enough',
#   'want',
#   'richardbranson'],
#  ['friday',
#   'even',
#   'welcom',
#   'new',
#   'mre',
#   'phd',
#   'student',
#   'walk',
#   'tour',
#   'citi',
#   'intern',
#   'student',
#   'enjoy',
#   'see',
#   'sight',
#   'sydney',
#   'cityofsydney',
#   'macquarieuniexperi',
#   'macquari',
#   'uni',
#   'mqintl',
#   'mqscieng'],
#  ['excit',
#   'publish',
#   'bpm',
#   'newslett',
#   '1',
#   '2018',
#   'first',
#   'one',
#   'download',
#   'http',
#   'tinyurl',
#   'com',
#   'y7ync633',
#   'bpmconf',
#   'bpm2018'],
#  ['social',
#   'network',
#   'amplifi',
#   'neg',
#   'posit',
#   'great',
#   'articl',
#   'http',
#   'washingtonmonthli',
#   'com',
#   'magazin',
#   'januari',
#   'februari',
#   'march',
#   '2018',
#   'fix',
#   'facebook',
#   'fix',
#   'us',
#   'cc',
#   'webfound'],
#  ['welcom',
#   'offici',
#   'depart',
#   'comput',
# ...

# %%
import csv #libary to export dataframes to csv file

with open("out.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(new_list)

# %% [markdown]
# n = 0
# for z in data1:
#     collection.update_one(
#     {"text" : data1[n]},
#     {"$set" : {"keywords" : }})
